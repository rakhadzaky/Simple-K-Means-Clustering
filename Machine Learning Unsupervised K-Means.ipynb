# %%
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

import matplotlib.cm as cm
from sklearn.cluster import KMeans

# %%
X = pd.read_csv("DataSet.csv")
X = X.drop(["No"], axis=1)
X
# Out:
#      x   y
# 0   18  40
# 1   28  23
# 2   57   3
# 3   75  50
# 4   39  84
# 5   89  86
# 6   16  70
# 7   56  30
# 8   43  46
# 9   65   1
# 10  47  48
# 11  28  68
# 12  54  83
# 13  83  16
# 14  68  86
# 15  56   9
# 16   4  39
# 17   8  79
# 18  14  66
# 19  38  73
# 20   4   1
# 21  59  21
# 22  84  35
# 23  73  63
# 24   7  69
# 25  80  25
# 26  52   1
# 27  31   8
# 28  42  35
# 29  25  81

# %%
n_clusters = 3
random_state = np.random.RandomState(0)
km = KMeans(n_clusters=n_clusters, random_state=random_state).fit(X)
km.cluster_centers_
# Out:
# array([[73.83333333, 67.16666667],
#        [23.91666667, 63.58333333],
#        [51.08333333, 14.41666667]])

# %%
for i in range(30):
    if(km.labels_[i] == 0):
        plt.plot(X['x'][i], X['y'][i], 'bo')
    if(km.labels_[i] == 1):
        plt.plot(X['x'][i], X['y'][i], 'ro')
    if(km.labels_[i] == 2):
        plt.plot(X['x'][i], X['y'][i], 'go')

for i in range(3):
    plt.plot(km.cluster_centers_[i][0], km.cluster_centers_[i][1], 'ko')
        
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
